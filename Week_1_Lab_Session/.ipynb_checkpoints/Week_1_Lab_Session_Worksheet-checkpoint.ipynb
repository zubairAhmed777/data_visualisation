# %% [markdown]
# # Week 1 Lab Session Worksheet: Anatomy of a Figure
#
# # Environment Setup
#
# Python-based computing environments are one of the most popular options among data scientists. Python provides standard, in-built functionalities that can be extended by importing third-party packages. The most common third-party libraries we will use are [Matplotlib](https://matplotlib.org/stable/users/index.html), [Plotly](https://plotly.com/), [Seaborn](https://seaborn.pydata.org) and [NumPy](https://numpy.org).
#
# # Jupyter Notebook
# We will use the Jupyter Notebook to create and share visualisations in this module. The classic Notebook interface is a document-oriented interface that allows you to create, view, and execute Python code and import various libraries into Jupyter Notebook. I recommend installing and using [Jupyter Desktop](https://github.com/jupyterlab/jupyterlab-desktop) on your local machine.
#
# ## Objective
# In this lab session, you'll explore the various components of a Matplotlib figure and learn how to customise them using the ["Anatomy of a figure"](https://matplotlib.org/stable/gallery/showcase/anatomy.html).
#
# ## Prerequisites
# - Basic knowledge of Python
# - Python environment
# - Matplotlib library installed
# - Jupyter Notebook

# %%
#First, let's import the necessary libraries:
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Circle
from matplotlib.patheffects import withStroke
from matplotlib.ticker import AutoMinorLocator, MultipleLocator

# %% [markdown]
# ## 1. Setting up the Figure and Axes
#
# In this section, we'll create a new figure with a specific size and add an axes to it with custom positioning and aspect ratio.

# %%
fig = plt.figure(figsize=(7.5, 7.5))
ax = fig.add_axes([0.2, 0.17, 0.68, 0.7], aspect=1)

ax.set_xlim(0, 4)
ax.set_ylim(0, 4)

plt.show()

# %% [markdown]
# ## 2. Customising Ticks and Grid
#
# a) Set major and minor tick locators for both x and y axes.
#
# b) Customize tick parameters (width, length, size) for major and minor ticks.
#
# c) Add a grid to the plot with custom style.

# %%
fig = plt.figure(figsize=(7.5, 7.5))
ax = fig.add_axes([0.2, 0.17, 0.68, 0.7], aspect=1)
ax.set_xlim(0, 4)
ax.set_ylim(0, 4)

ax.xaxis.set_major_locator(MultipleLocator(1.000))
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_major_locator(MultipleLocator(1.000))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))

ax.tick_params(which='major', width=1.0, length=10, labelsize=14)
ax.tick_params(which='minor', width=1.0, length=5, labelsize=10, labelcolor='0.25')

ax.grid(linestyle="--", linewidth=0.5, color='.25', zorder=-10)

plt.show()

# %% [markdown]
# ## 3. Plotting Data
#
# Let's generate some sample data and plot it on our figure.

# %%
fig = plt.figure(figsize=(7.5, 7.5))
ax = fig.add_axes([0.2, 0.17, 0.68, 0.7], aspect=1)
ax.set_xlim(0, 4)
ax.set_ylim(0, 4)



X = np.linspace(0.5, 3.5, 100)
Y1 = 3 + np.cos(X)
Y2 = 1 + np.cos(1 + X/0.75)/2
Y3 = np.random.uniform(Y1, Y2, len(X))

ax.plot(X, Y1, c='C0', lw=2.5, label="Blue signal", zorder=10)
ax.plot(X, Y2, c='C1', lw=2.5, label="Orange signal")
ax.plot(X[::3], Y3[::3], linewidth=0, markersize=9,
        marker='s', markerfacecolor='none', markeredgecolor='C4',
        markeredgewidth=2.5)

plt.show()

# %% [markdown]
# ## 4. Adding Labels and Legend
#
# Now, let's add a title, axis labels, and a legend to our plot.

# %%
fig = plt.figure(figsize=(7.5, 7.5))
ax = fig.add_axes([0.2, 0.17, 0.68, 0.7], aspect=1)
ax.set_xlim(0, 4)
ax.set_ylim(0, 4)



ax.set_title("Anatomy of a figure", fontsize=20, verticalalignment='bottom')
ax.set_xlabel("x Axis label", fontsize=14)
ax.set_ylabel("y Axis label", fontsize=14)
ax.legend(loc="upper right", fontsize=14)
 
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## 5. Annotation
#
# Let's create a function to add custom annotations to our plot.

# %%
fig = plt.figure(figsize=(7.5, 7.5))
ax = fig.add_axes([0.2, 0.17, 0.68, 0.7], aspect=1)
ax.set_xlim(0, 4)
ax.set_ylim(0, 4)


royal_blue = [0, 20/256, 82/256]

def annotate(x, y, text, code):
    # Circle marker
    c = Circle((x, y), radius=0.15, clip_on=False, zorder=10, linewidth=2.5,
               edgecolor=royal_blue + [0.6], facecolor='none',
               path_effects=[withStroke(linewidth=7, foreground='white')])
    ax.add_artist(c)

    # Text and code with path effects
    for path_effects in [[withStroke(linewidth=7, foreground='white')], []]:
        color = 'white' if path_effects else royal_blue
        ax.text(x, y-0.2, text, zorder=100,
                ha='center', va='top', weight='bold', color=color,
                style='italic', fontfamily='monospace',
                path_effects=path_effects)

        color = 'white' if path_effects else 'black'
        ax.text(x, y-0.33, code, zorder=100,
                ha='center', va='top', weight='normal', color=color,
                fontfamily='monospace', fontsize='medium',
                path_effects=path_effects)

# Add annotations
annotate(3.5, -0.13, "Minor tick label", "ax.xaxis.set_minor_formatter")
annotate(-0.03, 1.0, "Major tick", "ax.yaxis.set_major_locator")
annotate(0.00, 3.75, "Minor tick", "ax.yaxis.set_minor_locator")
annotate(-0.15, 3.00, "Major tick label", "ax.yaxis.set_major_formatter")
annotate(1.68, -0.39, "xlabel", "ax.set_xlabel")
annotate(-0.38, 1.67, "ylabel", "ax.set_ylabel")
annotate(1.52, 4.15, "Title", "ax.set_title")
annotate(1.75, 2.80, "Line", "ax.plot")
annotate(2.25, 1.54, "Markers", "ax.scatter")
annotate(3.00, 3.00, "Grid", "ax.grid")
annotate(3.60, 3.58, "Legend", "ax.legend")
annotate(2.5, 0.55, "Axes", "fig.subplots")
annotate(4, 4.5, "Figure", "plt.figure")
annotate(0.65, 0.01, "x Axis", "ax.xaxis")
annotate(0, 0.36, "y Axis", "ax.yaxis")
annotate(4.0, 0.7, "Spine", "ax.spines")

plt.show()

# %% [markdown]
# ## 6. Final Touches
#
# Finally, let's add a frame around the entire figure.

# %%
fig = plt.figure(figsize=(7.5, 7.5))
ax = fig.add_axes([0.2, 0.17, 0.68, 0.7], aspect=1)
ax.set_xlim(0, 4)
ax.set_ylim(0, 4)


fig.patch.set(linewidth=4, edgecolor='0.5')
plt.show()

# %% [markdown]
# # Matplotlib Exercises: Anatomy of a Figure
#
# These exercises are designed to help you practice and reinforce your understanding of Matplotlib's figure anatomy.
#
# Complete each exercise using the provided template code and Matplotlib [User guide](https://matplotlib.org/stable/users/index.html).
#
# ## Setup
# First, run the following cell to set up the base figure:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create data
x = np.linspace(0, 10, 100)
y1 = 4 + 2 * np.sin(2 * x)
y2 = 4 + 2 * np.cos(2 * x)

# Create figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plot data
ax.plot(x, y1, label='sin')
ax.plot(x, y2, label='cos')

# Set title and labels
ax.set_title("Trigonometric Functions")
ax.set_xlabel("x")
ax.set_ylabel("y")

# Add legend
ax.legend()

plt.show()

# %% [markdown]
# ## Exercises
#
# **1. Customise Tick Labels:**
#
# Modify the x-axis tick labels to show π multiples $(0, π/2, π, 3π/2, 2π)$ instead of numbers.
#
# *Hint:*  Use ```ax.set_xticks()``` and ```ax.set_xticklabels()```.
#
# **2. Add Grid:**
#
# Add a grid to the plot with dashed lines. Make the major grid lines darker and thicker than the minor grid lines.
#
# *Hint:* ```Use ax.grid()``` with different parameters for major and minor grids.
#
# **3. Customise Spines:**
#
# Move the left and bottom spines to $x=0$ and $y=0$, and remove the top and right spines.
#
# *Hint:* Use ```ax.spines['left'].set_position()``` and ```ax.spines['top'].set_visible()```.
#
# **4. Add Text Annotation:**
#
# Add a text annotation pointing out the maximum point of the sine wave.
#
# *Hint:* Use ```ax.annotate()``` with ```xytext``` and ```arrowprops``` parameters.
#
# **5. Add a Secondary Y-axis:**
#
# Add a secondary y-axis on the right side of the plot, showing the values in radians (original values divided by $π$).
#
# *Hint:* Use ```ax.twinx()``` to create a secondary axis.
#
# **6. Customise Figure Style:**
#
# Change the overall style of the figure and modify the colour cycle to use pastel colours.
# Hint: Use ```plt.style.use()``` and ```plt.rcParams['axes.prop_cycle']```.
#
# **7. Add Inset Axes:**
# Create smaller axes inside the main plot, showing a zoomed-in view of the region where the sine and cosine curves intersect.
#
# *Hint:* ```Use ax.inset_axes()``` and ```ax.indicate_inset_zoom()```.
#
# For each exercise, start with the base code provided in the setup section and add your modifications.
#
# After completing each exercise, make sure to display the plot using ```plt.show()```.

# %%
#Start your solutions from this cell
